# %%
import pandas
import sklearn.metrics
data = pandas.read_csv('classification.csv')
cnfmtr = sklearn.metrics.confusion_matrix(data['true'], data['pred'])
TP = FP = TN = FN = 0
TN = cnfmtr[0][0]
FN = cnfmtr[1][0]
TP = cnfmtr[1][1]
FP = cnfmtr[0][1]
fout = open('./ans/4tfpn', 'w')
print(*[TP, FP, FN, TN], file=fout)
fout.close()

fout = open('./ans/5classmetr', 'w')
print(*np.round([sklearn.metrics.accuracy_score(data['true'], data['pred']),
      sklearn.metrics.precision_score(data['true'], data['pred']),
      sklearn.metrics.recall_score(data['true'], data['pred']),
      sklearn.metrics.f1_score(data['true'], data['pred'])], 2), file=fout)
fout.close()

data2 = pandas.read_csv('scores.csv')
max_sqr = 0
max_prec = 0
for col in data2:
    if col == 'true':
        continue
    scr = sklearn.metrics.roc_auc_score(data2['true'], data2[col])
    precision, recall, thresholds = sklearn.metrics.precision_recall_curve(data2['true'], data2[col])
    for i in range(len(thresholds)):
        if recall[i] <= 0.7:
            break
    print(precision[i])
    if precision[i] > max_prec:
        max_prec = precision[i]
        ans2 = col
    if scr > max_sqr:
        max_sqr = scr
        ans = col
fout = open('./ans/6maxsqr', 'w', encoding='utf-8')
print(ans, file=fout, end='')
fout.close()

fout = open('./ans/7maxprec', 'w', encoding='utf-8')
print(ans2, file=fout, end='')
fout.close()
print(ans2)
data2
# Out:
# 0.6126126126126126
# 0.6181818181818182
# 0.591304347826087
# 0.6770833333333334
# score_tree
#      true  score_logreg  score_svm  score_knn  score_tree
# 0       0      0.683832   0.145976   0.787063    0.500000
# 1       1      0.801966   0.239511   1.000000    0.833333
# 2       0      0.382315  -0.245701   0.000000    0.000000
# 3       1      0.506797  -0.137058   0.000000    0.105263
# 4       1      0.488781  -0.154148   0.000000    0.105263
# 5       0      0.108506  -0.790864   0.000000    0.000000
# 6       0      0.413749  -0.185143   0.283053    0.363636
# 7       0      0.961081   0.830973   1.000000    1.000000
# 8       0      0.055733  -0.872805   0.000000    0.100000
# 9       0      0.168708  -0.518390   0.000000    0.100000
# 10      1      0.504716  -0.103459   0.698631    0.833333
# 11      1      0.700781   0.104391   1.000000    0.833333
# 12      0      0.310665  -0.301488   0.676880    0.363636
# 13      0      0.784460   0.195189   1.000000    0.923077
# ...
